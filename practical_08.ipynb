# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules
# Transaction Dataset
transactions = [
['Bread', 'Milk'],
['Bread', 'Butter'],
['Bread', 'Milk', 'Butter'],
['Milk', 'Butter'],
['Bread', 'Milk'],
['Bread', 'Milk', 'Butter'],
['Milk', 'Bread'],
['Bread', 'Butter']
]
# Convert transactions into DataFrame
te = TransactionEncoder()
te_data = te.fit(transactions).transform(transactions)
df = pd.DataFrame(te_data, columns=te.columns_)
print("Transaction Dataset")
print(df)

# Find Frequent Itemsets
frequent_itemsets = apriori(
df,
min_support=0.5,
use_colnames=True
)
print("\nFrequent Itemsets")
print(frequent_itemsets)

# Generate Association Rules
rules = association_rules(
frequent_itemsets,
metric="confidence",
min_threshold=0.6
)
print("\nAssociation Rules")
print(rules[['antecedents', 'consequents',
'support', 'confidence', 'lift']])
# Out:
# Transaction Dataset
#    Bread  Butter   Milk
# 0   True   False   True
# 1   True    True  False
# 2   True    True   True
# 3  False    True   True
# 4   True   False   True
# 5   True    True   True
# 6   True   False   True
# 7   True    True  False
#
# Frequent Itemsets
#    support                    itemsets
# 0    0.875          frozenset({Bread})
# 1    0.625         frozenset({Butter})
# 2    0.750           frozenset({Milk})
# 3    0.500  frozenset({Butter, Bread})
# 4    0.625    frozenset({Bread, Milk})
#
# Association Rules
#            antecedents         consequents  support  confidence      lift
# 0  frozenset({Butter})  frozenset({Bread})    0.500    0.800000  0.914286
# 1   frozenset({Bread})   frozenset({Milk})    0.625    0.714286  0.952381
# 2    frozenset({Milk})  frozenset({Bread})    0.625    0.833333  0.952381
