# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsClassifier

from sklearn.metrics import (
mean_absolute_error,
mean_squared_error,
r2_score,
accuracy_score,
confusion_matrix
)


# PART A: LINEAR REGRESSION
#

# Dataset
data_reg = {
'Study_Hours': [1, 2, 3, 4, 5, 6, 7],
'Marks': [35, 45, 50, 60, 70, 80, 85]
}

df_reg = pd.DataFrame(data_reg)

print("LINEAR REGRESSION DATASET")
print(df_reg)

# Input and Output
X = df_reg[['Study_Hours']]
Y = df_reg['Marks']

# Split Dataset
X_train, X_test, Y_train, Y_test = train_test_split(
X, Y, test_size=0.3, random_state=42
)

# Create and Train Model
reg_model = LinearRegression()
reg_model.fit(X_train, Y_train)

# Prediction
Y_pred = reg_model.predict(X_test)

# Evaluation Metrics
mae = mean_absolute_error(Y_test, Y_pred)
mse = mean_squared_error(Y_test, Y_pred)
r2 = r2_score(Y_test, Y_pred)

print("\nLINEAR REGRESSION EVALUATION")
print("MAE :", round(mae, 2))
print("MSE :", round(mse, 2))
print("R2 Score :", round(r2, 2))

#
# PART B: KNN CLASSIFICATION
# Student Dataset
data_knn = {
'Study_Hours': [2, 3, 4, 5, 6, 7, 8, 9, 3, 6, 7, 8],
'Attendance': [55, 60, 65, 70, 75, 80, 85, 90, 58, 72,
82, 88],
'Result': [
'Fail', 'Fail', 'Fail', 'Pass',
'Pass', 'Pass', 'Pass', 'Pass',
'Fail', 'Pass', 'Pass', 'Pass'
]
}

df_knn = pd.DataFrame(data_knn)

print("\nKNN DATASET")
print(df_knn)

# Input Features and Target
X = df_knn[['Study_Hours', 'Attendance']]
Y = df_knn['Result']

# Split Dataset
X_train, X_test, Y_train, Y_test = train_test_split(
X, Y, test_size=0.25, random_state=42
)

# Create KNN Model
knn_model = KNeighborsClassifier(n_neighbors=3)

# Train Model
knn_model.fit(X_train, Y_train)

# Prediction
Y_pred = knn_model.predict(X_test)

# Evaluation
accuracy = accuracy_score(Y_test, Y_pred)
cm = confusion_matrix(Y_test, Y_pred)

print("\nKNN EVALUATION")
print("Accuracy :", round(accuracy * 100, 2), "%")

print("\nConfusion Matrix")
print(cm)
# Out:
# LINEAR REGRESSION DATASET
#    Study_Hours  Marks
# 0            1     35
# 1            2     45
# 2            3     50
# 3            4     60
# 4            5     70
# 5            6     80
# 6            7     85
#
# LINEAR REGRESSION EVALUATION
# MAE : 2.33
# MSE : 5.86
# R2 Score : 0.98
#
# KNN DATASET
#     Study_Hours  Attendance Result
# 0             2          55   Fail
# 1             3          60   Fail
# 2             4          65   Fail
# 3             5          70   Pass
# 4             6          75   Pass
# 5             7          80   Pass
# 6             8          85   Pass
# 7             9          90   Pass
# 8             3          58   Fail
# 9             6          72   Pass
# 10            7          82   Pass
# 11            8          88   Pass
#
# KNN EVALUATION
# Accuracy : 100.0 %
#
# Confusion Matrix
# [[1 0]
#  [0 2]]
